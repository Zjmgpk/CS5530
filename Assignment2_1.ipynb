# %% [markdown]
# <a href="https://colab.research.google.com/github/Zjmgpk/CS5530/blob/main/Assignment2_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import pandas
import sklearn

# %%
df = pandas.read_csv("/content/drive/MyDrive/Colab Notebooks/Assignment 2/Assignment 2_1/Raw_Data/train.csv")
df = df.drop('Unnamed: 0', axis=1)
df
# Out:
#                                   Name    Location  Year  Kilometers_Driven  \
# 0     Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 1                         Honda Jazz V     Chennai  2011              46000
# 2                    Maruti Ertiga VDI     Chennai  2012              87000
# 3      Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
# 4               Nissan Micra Diesel XV      Jaipur  2013              86999
# ...                                ...         ...   ...                ...
# 5842                  Maruti Swift VDI       Delhi  2014              27365
# 5843          Hyundai Xcent 1.1 CRDi S      Jaipur  2015             100000
# 5844             Mahindra Xylo D4 BSIV      Jaipur  2012              55000
# 5845                Maruti Wagon R VXI     Kolkata  2013              46000
# 5846             Chevrolet Beat Diesel   Hyderabad  2011              47000
#
# ...

# %%
df_cleaned = df.dropna(subset=['New_Price'])
display(df_cleaned)
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 1                          Honda Jazz V  Chennai  2011              46000
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 8                      Maruti Ciaz Zeta    Kochi  2018              25692
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 18                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5827              Tata Bolt Revotron XT  Chennai  2016              10000
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 5833           Maruti Vitara Brezza VDi     Pune  2016              37208
# 5838               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 5842                   Maruti Swift VDI    Delhi  2014              27365
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# ...

# %% [markdown]
# I dropped the NaN of the New_Price column due beacause of how few values there were in the column. With there only being 815 out of 5847, it wouldnt have been possible to fill each of the missing values.

# %%
filtered_df = df_cleaned[(df_cleaned['Kilometers_Driven'] == 50000) & (df_cleaned['Fuel_Type'] == 'Electric')]
display(filtered_df)
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4313  Mahindra E Verito D4  Chennai  2016              50000  Electric
#
#      Transmission Owner_Type Mileage Engine   Power  Seats   New_Price  Price
# 4313    Automatic      First     NaN  72 CC  41 bhp    5.0  13.58 Lakh   13.0

# %%
rows_with_nan = df_cleaned[df_cleaned.isnull().any(axis=1)]
display(rows_with_nan)
# Out:
#                       Name Location  Year  Kilometers_Driven Fuel_Type  \
# 4313  Mahindra E Verito D4  Chennai  2016              50000  Electric
#
#      Transmission Owner_Type Mileage Engine   Power  Seats   New_Price  Price
# 4313    Automatic      First     NaN  72 CC  41 bhp    5.0  13.58 Lakh   13.0

# %%
df_cleaned = df_cleaned.drop(4313)
display(df_cleaned)
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 1                          Honda Jazz V  Chennai  2011              46000
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 8                      Maruti Ciaz Zeta    Kochi  2018              25692
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 18                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5827              Tata Bolt Revotron XT  Chennai  2016              10000
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 5833           Maruti Vitara Brezza VDi     Pune  2016              37208
# 5838               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 5842                   Maruti Swift VDI    Delhi  2014              27365
#
#      Fuel_Type Transmission Owner_Type     Mileage   Engine       Power  \
# ...

# %% [markdown]
# Row 4313 was dropped due to no other row relating to it. Since there was no other row that was related to it in the car's model, I wouldn't be able to calculate a value for the milage.

# %%
df_cleaned['Mileage'] = df_cleaned['Mileage'].str.replace(' kmpl', '')
df_cleaned['Mileage'] = df_cleaned['Mileage'].str.replace(' km/kg', '')
df_cleaned['Engine'] = df_cleaned['Engine'].str.replace(' CC', '')
df_cleaned['Power'] = df_cleaned['Power'].str.replace(' bhp', '')
df_cleaned['New_Price'] = df_cleaned['New_Price'].str.replace(' Lakh', '')
df_cleaned['New_Price'] = df_cleaned['New_Price'].str.replace(' Cr', '')
df_cleaned
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 1                          Honda Jazz V  Chennai  2011              46000
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 8                      Maruti Ciaz Zeta    Kochi  2018              25692
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 18                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5827              Tata Bolt Revotron XT  Chennai  2016              10000
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 5833           Maruti Vitara Brezza VDi     Pune  2016              37208
# 5838               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 5842                   Maruti Swift VDI    Delhi  2014              27365
#
#      Fuel_Type Transmission Owner_Type Mileage Engine   Power  Seats  \
# ...

# %%
df_cleaned = pandas.get_dummies(df_cleaned, columns=['Fuel_Type', 'Transmission'], dtype=int)
display(df_cleaned)
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 1                          Honda Jazz V  Chennai  2011              46000
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 8                      Maruti Ciaz Zeta    Kochi  2018              25692
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 18                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5827              Tata Bolt Revotron XT  Chennai  2016              10000
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 5833           Maruti Vitara Brezza VDi     Pune  2016              37208
# 5838               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 5842                   Maruti Swift VDI    Delhi  2014              27365
#
#      Owner_Type Mileage Engine   Power  Seats New_Price  Price  \
# ...

# %%
df_cleaned['Car_Age'] = 2025 - df_cleaned['Year']
display(df_cleaned)
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 1                          Honda Jazz V  Chennai  2011              46000
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 8                      Maruti Ciaz Zeta    Kochi  2018              25692
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 18                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5827              Tata Bolt Revotron XT  Chennai  2016              10000
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 5833           Maruti Vitara Brezza VDi     Pune  2016              37208
# 5838               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 5842                   Maruti Swift VDI    Delhi  2014              27365
#
#      Owner_Type Mileage Engine   Power  Seats New_Price  Price  \
# ...

# %% [markdown]
# dplyr in Python:
#
# 1) Select:

# %%
selected_df = df_cleaned[['Name', 'Year']]
display(selected_df)
# Out:
#                                    Name  Year
# 1                          Honda Jazz V  2011
# 5     Toyota Innova Crysta 2.8 GX AT 8S  2016
# 8                      Maruti Ciaz Zeta  2018
# 13          Mitsubishi Pajero Sport 4X4  2014
# 18                    BMW 3 Series 320d  2014
# ...                                 ...   ...
# 5827              Tata Bolt Revotron XT  2016
# 5830      Volkswagen Vento 1.6 Highline  2011
# 5833           Maruti Vitara Brezza VDi  2016
# 5838               Honda Brio 1.2 VX MT  2013
# 5842                   Maruti Swift VDI  2014
#
# [814 rows x 2 columns]

# %% [markdown]
# 2) Filter:

# %%
selected_df = df_cleaned[(df_cleaned['Kilometers_Driven'] > 100000) & (df_cleaned['Price'] > 10) & (df_cleaned['Car_Age']  > 10)]
display(selected_df)
# Out:
#                              Name   Location  Year  Kilometers_Driven  \
# 13    Mitsubishi Pajero Sport 4X4      Delhi  2014             110000
# 913   Mitsubishi Pajero Sport 4X4  Bangalore  2013             132000
# 996    Toyota Fortuner 2.8 4WD MT      Kochi  2013             105072
# 2178   Toyota Fortuner 2.8 4WD MT  Hyderabad  2010             110000
# 2211   Toyota Fortuner 2.8 4WD MT     Mumbai  2010             140000
# 3525   Toyota Fortuner 2.8 4WD MT      Kochi  2011             169006
#
#      Owner_Type Mileage Engine   Power  Seats New_Price  Price  \
# 13        First    13.5   2477  175.56    7.0     32.01  15.00
# 913       First    13.5   2477  175.56    7.0      34.6  12.49
# 996       First   14.24   2755   174.5    7.0     36.69  13.28
# 2178      First   14.24   2755   174.5    7.0     37.51  13.70
# 2211      First   14.24   2755   174.5    7.0     37.46  10.75
# 3525      First   14.24   2755   174.5    7.0     36.69  10.64
#
# ...

# %% [markdown]
# 3) Rename:

# %%
renamed_df = df_cleaned.rename(columns={'Name': 'Model_Name', 'Seats':'No. of Seats'})
display(renamed_df)
# Out:
#                              Model_Name Location  Year  Kilometers_Driven  \
# 1                          Honda Jazz V  Chennai  2011              46000
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 8                      Maruti Ciaz Zeta    Kochi  2018              25692
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 18                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5827              Tata Bolt Revotron XT  Chennai  2016              10000
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 5833           Maruti Vitara Brezza VDi     Pune  2016              37208
# 5838               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 5842                   Maruti Swift VDI    Delhi  2014              27365
#
#      Owner_Type Mileage Engine   Power  No. of Seats New_Price  Price  \
# ...

# %% [markdown]
# 4) Mutate

# %%
df_2 = df_cleaned.copy()
df_2['Price_Per_Kilometer'] = df_2['Price']/df_2['Kilometers_Driven']
display(df_2)
# Out:
#                                    Name Location  Year  Kilometers_Driven  \
# 1                          Honda Jazz V  Chennai  2011              46000
# 5     Toyota Innova Crysta 2.8 GX AT 8S   Mumbai  2016              36000
# 8                      Maruti Ciaz Zeta    Kochi  2018              25692
# 13          Mitsubishi Pajero Sport 4X4    Delhi  2014             110000
# 18                    BMW 3 Series 320d    Kochi  2014              32982
# ...                                 ...      ...   ...                ...
# 5827              Tata Bolt Revotron XT  Chennai  2016              10000
# 5830      Volkswagen Vento 1.6 Highline   Mumbai  2011              38000
# 5833           Maruti Vitara Brezza VDi     Pune  2016              37208
# 5838               Honda Brio 1.2 VX MT    Delhi  2013              33746
# 5842                   Maruti Swift VDI    Delhi  2014              27365
#
#      Owner_Type Mileage Engine   Power  Seats New_Price  Price  \
# ...

# %% [markdown]
# 5) Arrange

# %%
arranged_df = df_cleaned.sort_values(by='Year', ascending=True)
display(arranged_df)
# Out:
#                                     Name    Location  Year  Kilometers_Driven  \
# 4723               Hyundai Santro D Lite     Chennai  2001             140000
# 5414               Honda CR-V Petrol 2WD     Chennai  2004             135000
# 337                     Skoda Octavia RS      Jaipur  2005             100000
# 2058      Ford Freestyle Titanium Petrol      Mumbai  2007               1261
# 1323           Hyundai Verna CRDi 1.6 SX   Hyderabad  2008              96578
# ...                                  ...         ...   ...                ...
# 5644        Skoda Rapid 1.6 MPI Ambition  Coimbatore  2019              21214
# 1160   Volkswagen Polo 1.0 MPI Trendline   Hyderabad  2019               1000
# 1322  Hyundai Grand i10 1.2 Kappa Sportz       Kochi  2019              18453
# 165     Hyundai Grand i10 1.2 Kappa Asta     Kolkata  2019               1000
# 226       Toyota Innova Crysta 2.8 GX AT       Kochi  2019              14165
#
# ...

# %% [markdown]
# 6) Summarize with Group By:

# %%
summarized_df = df_cleaned.groupby('Name')['Kilometers_Driven'].mean()
display(summarized_df)
# Out:
# Name
# Audi A3 35 TDI Premium Plus           39000.000000
# Audi A4 30 TFSI Premium Plus          61221.000000
# Audi A4 35 TDI Premium Plus           33534.666667
# Audi A4 35 TDI Technology             29500.000000
# Audi A6 35 TDI Matrix                 43706.000000
#                                           ...
# Volkswagen Vento 1.5 TDI Trendline    47000.000000
# Volkswagen Vento 1.6 Comfortline      33576.500000
# Volkswagen Vento 1.6 Highline         42143.666667
# Volvo S60 D4 Momentum                 51000.000000
# Volvo V40 D3 R Design                 38000.000000
# Name: Kilometers_Driven, Length: 317, dtype: float64
